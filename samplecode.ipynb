# %% [markdown]
# <a href="https://colab.research.google.com/github/gojiteji/2020portfolio/blob/master/samplecode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Please select higher ram and better gpu
! git clone https://github.com/gojiteji/stable-diffusion
# %cd stable-diffusion
# !pip install -r requirements.txt
# !pip uninstall -y torchtext # on colab we need to remove torchtext

# %%
# get wieghts
# !wget https://storage.googleapis.com/sd_distribute/main.ckpt

# %%
# Run the model
#images are saved in '~/stable-diffusion/outputs/generated_qr/'
!(python scripts/txt2img.py \
    --prompt 'How are you?' \
    --outdir 'outputs/generated_qr' \
    --H 256 --W 256 \
    --n_samples 1 \
    --config 'configs/stable-diffusion/text2QR.yaml' \
    --ckpt '/content/drive/MyDrive/stable-diffusion/main.ckpt')

# %%
from PIL import Image
im = Image.open('outputs/generated_qr/samples/00001.png')
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FB8D09246D0>
